# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/Equilibrium/blob/main/Deep_dive_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import plotly.express as px
import pandas as pd
from google.cloud import bigquery
from google.colab import auth

# %%
auth.authenticate_user()
project_id = 'project-equilibrium-474307'
client = bigquery.Client(project_id)
print('Authentication Successfull')
# Out:
# Authentication Successfull

# %%
master_query = f"""
WITH LatestPerformance AS (
  SELECT
    employee_id,
    performance_score,
    potential_score,
    ROW_NUMBER() OVER(PARTITION BY employee_id ORDER BY review_date DESC) AS rn
  FROM
    `project-equilibrium-474307.hr_analytics.performance`
),
LatestCompensation AS (
  SELECT
    employee_id,
    base_salary,
    bonus,
    stock_options,
    ROW_NUMBER() OVER(PARTITION BY employee_id ORDER BY effective_date DESC) AS rn
  FROM
    `project-equilibrium-474307.hr_analytics.compensation`
)
SELECT
  e.employee_id,
  e.gender,
  e.department,
  e.job_level,
  e.hire_date,
  e.termination_date,
  lc.base_salary,
  lc.bonus,
  lc.stock_options,
  lp.performance_score,
  lp.potential_score,
  CASE WHEN e.termination_date IS NOT NULL THEN 1 ELSE 0 END AS is_attrited,
  DATE_DIFF(COALESCE(e.termination_date, '2025-10-16'), e.hire_date, DAY) AS tenure_in_days
FROM
  `project-equilibrium-474307.hr_analytics.employees` AS e
LEFT JOIN LatestCompensation AS lc
  ON e.employee_id = lc.employee_id AND lc.rn = 1
LEFT JOIN LatestPerformance AS lp
  ON e.employee_id = lp.employee_id AND lp.rn = 1
WHERE
  lc.base_salary IS NOT NULL AND lp.performance_score IS NOT NULL;
"""

# %%
pandas_df = client.query(master_query).to_dataframe()
df_people = pl.from_pandas(pandas_df)

# %%
print(f'Data Successfully Extracted. Shape:{df_people.shape}')
# Out:
# Data Successfully Extracted. Shape:(2500, 13)

# %%
df_people.head()
# Out:
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ employee_ ┆ gender    ┆ departmen ┆ job_level ┆ … ┆ performan ┆ potential ┆ is_attrit ┆ tenure_i │
# │ id        ┆ ---       ┆ t         ┆ ---       ┆   ┆ ce_score  ┆ _score    ┆ ed        ┆ n_days   │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆           ┆ str       ┆           ┆   ┆ i64       ┆ i64       ┆ i64       ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8273      ┆ Male      ┆ Finance   ┆ T1        ┆ … ┆ 5         ┆ 2         ┆ 0         ┆ 1703     │
# │ 8790      ┆ Non-Binar ┆ Sales     ┆ T1        ┆ … ┆ 5         ┆ 3         ┆ 1         ┆ 8        │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 7634      ┆ Female    ┆ Data      ┆ T5        ┆ … ┆ 2         ┆ 2         ┆ 1         ┆ 507      │
# │ 3829      ┆ Female    ┆ Product   ┆ T1        ┆ … ┆ 1         ┆ 2         ┆ 1         ┆ 33       │
# │ 4618      ┆ Non-Binar ┆ Product   ┆ T2        ┆ … ┆ 3         ┆ 5         ┆ 0         ┆ 462      │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# # *Compensation Equity Box Plot*

# %%
fig_box = px.box(
    df_people.to_pandas(),
    x='department',
    y='base_salary',
    color='gender',
    title='Compensation Distribution by Department and Gender',
    labels={'base_salary':'Base Salary (€)','department':'Department','gender':'Gender'},
    notched=True # Adds a 'notch' to show the confidence interval for the median
)

fig_box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="483d677c-7db9-4a8f-a0ea-2eb9afa1cbae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("483d677c-7db9-4a8f-a0ea-2eb9afa1cbae")) {                    Plotly.newPlot(                        "483d677c-7db9-4a8f-a0ea-2eb9afa1cbae",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Male\u003cbr\u003eDepartment=%{x}\u003cbr\u003eBase Salary (€)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#636efa"},"name":"Male","notched":true,"offsetgroup":"Male","orientation":"v","showlegend":true,"x":["Finance","Product","Finance","Data","Human Resources","Data","Sales","Engineering","Product","Human Resources","Data","Finance","Human Resources","Finance","Engineering","Finance","Finance","Finance","Human Resources","Engineering","Product","Engineering","Data","Finance","Engineering","Sales","Product","Data","Human Resources","Sales","Data","Sales","Data","Engineering","Finance","Finance","Sales","Sales","Engineering","Human Resources","Engineering","Human Resources","Engineering","Sales","Human Resources","Human Resources","Product","Engineering","Engineering","Human Resources","Data","Data","Finance","Sales","Product","Data","Human Resources","Engineering","Engineering","Sales","Product","Finance","Finance","Engineering","Human Resources","Data","Sales","Engineering","Finance","Sales","Human Resources","Engineering","Finance","Product","Engineering","Finance","Sales","Finance","Finance","Sales","Engineering","Human Resources","Engineering","Product","Human Resources","Engineering","Human Resources","Finance","Sales","Human Resources","Product","Sales","Finance","Human Resources","Sales","Product","Human Resources","Data","Sales","Engineering","Engineering","Human Resources","Product","Product","Human Resources","Engineering","Sales","Engineering","Human Resources","Product","Human Resources","Finance","Sales","Human Resources","Finance","Human Resources","Data","Sales","Data","Sales","Finance","Data","Engineering","Product","Human Resources","Engineering","Product","Engineering","Product","Human Resources","Finance","Product","Engineering","Human Resources","Finance","Sales","Sales","Product","Data","Engineering","Sales","Human Resources","Human Resources","Finance","Engineering","Product","Product","Human Resources","Data","Sales","Finance","Finance","Human Resources","Finance","Engineering","Human Resources","Data","Human Resources","Sales","Finance","Sales","Human Resources","Human Resources","Engineering","Product","Human Resources","Finance","Engineering","Data","Engineering","Engineering","Sales","Finance","Sales","Data","Engineering","Human Resources","Sales","Sales","Finance","Engineering","Finance","Engineering","Engineering","Data","Engineering","Engineering","Data","Sales","Human Resources","Product","Data","Data","Product","Human Resources","Finance","Data","Finance","Human Resources","Human Resources","Engineering","Finance","Finance","Human Resources","Human Resources","Finance","Finance","Engineering","Sales","Data","Data","Engineering","Product","Product","Sales","Human Resources","Data","Engineering","Human Resources","Finance","Engineering","Engineering","Finance","Human Resources","Product","Sales","Human Resources","Engineering","Data","Engineering","Data","Data","Data","Engineering","Finance","Human Resources","Data","Finance","Sales","Engineering","Data","Product","Engineering","Product","Engineering","Data","Sales","Data","Finance","Finance","Finance","Human Resources","Finance","Human Resources","Data","Human Resources","Sales","Engineering","Product","Sales","Human Resources","Engineering","Sales","Human Resources","Sales","Sales","Product","Product", ...

# %% [markdown]
# # **Tenure & Attrition**

# %%
# Creating a new column in Polars for 'Attrition Status'
df_with_status = df_people.with_columns(
    pl.when(pl.col('is_attrited')==1)
    .then(pl.lit('Left'))
    .otherwise(pl.lit('Stayed'))
    .alias('Attrition Status')
)

display(df_with_status)
# Out:
# shape: (2_500, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ employee_ ┆ gender    ┆ departmen ┆ job_level ┆ … ┆ potential ┆ is_attrit ┆ tenure_in ┆ Attritio │
# │ id        ┆ ---       ┆ t         ┆ ---       ┆   ┆ _score    ┆ ed        ┆ _days     ┆ n Status │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆           ┆ str       ┆           ┆   ┆ i64       ┆ i64       ┆ i64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8273      ┆ Male      ┆ Finance   ┆ T1        ┆ … ┆ 2         ┆ 0         ┆ 1703      ┆ Stayed   │
# │ 8790      ┆ Non-Binar ┆ Sales     ┆ T1        ┆ … ┆ 3         ┆ 1         ┆ 8         ┆ Left     │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 7634      ┆ Female    ┆ Data      ┆ T5        ┆ … ┆ 2         ┆ 1         ┆ 507       ┆ Left     │
# │ 3829      ┆ Female    ┆ Product   ┆ T1        ┆ … ┆ 2         ┆ 1         ┆ 33        ┆ Left     │
# │ 4618      ┆ Non-Binar ┆ Product   ┆ T2        ┆ … ┆ 5         ┆ 0         ┆ 462       ┆ Stayed   │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 5970      ┆ Non-Binar ┆ Human     ┆ T2        ┆ … ┆ 4         ┆ 0         ┆ 1447      ┆ Stayed   │
# │           ┆ y         ┆ Resources ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 3563      ┆ Non-Binar ┆ Human     ┆ T3        ┆ … ┆ 1         ┆ 0         ┆ 1812      ┆ Stayed   │
# │           ┆ y         ┆ Resources ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2643      ┆ Male      ┆ Data      ┆ T3        ┆ … ┆ 3         ┆ 0         ┆ 943       ┆ Stayed   │
# │ 8038      ┆ Male      ┆ Sales     ┆ T2        ┆ … ┆ 4         ┆ 0         ┆ 1347      ┆ Stayed   │
# │ 5561      ┆ Male      ┆ Product   ┆ T4        ┆ … ┆ 5         ┆ 0         ┆ 1313      ┆ Stayed   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
fig_hist = px.histogram(
    df_with_status.to_pandas(),
    x='tenure_in_days',
    color='Attrition Status',
    barmode='overlay', # Lays one histogram on top of the other
    nbins=50,
    title='Employee Tenure Distribution (Stayed vs. Left)'
)

fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="76bb3174-0da0-4942-9cca-e4f7308b4684" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76bb3174-0da0-4942-9cca-e4f7308b4684")) {                    Plotly.newPlot(                        "76bb3174-0da0-4942-9cca-e4f7308b4684",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Attrition Status=Stayed\u003cbr\u003etenure_in_days=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stayed","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Stayed","nbinsx":50,"offsetgroup":"Stayed","orientation":"v","showlegend":true,"x":[1703,462,1519,1053,1159,1248,1407,549,815,467,1050,229,997,1053,472,1647,1254,870,1129,1454,966,1375,1707,498,502,404,1607,276,1804,1555,1272,597,1172,1197,1782,1674,268,429,939,765,781,612,959,1727,1511,1270,1714,384,1432,1662,1682,323,1036,98,547,1515,350,1113,363,32,1271,1128,1800,1379,859,181,1014,478,703,543,545,182,1431,242,1728,502,1086,46,353,975,1381,413,1322,512,303,539,494,1138,450,1343,1655,1504,464,1555,1541,530,563,1753,994,896,577,300,303,601,613,960,439,1551,767,543,777,1690,221,1547,664,1401,693,1160,1813,281,1804,568,398,1454,1631,1224,879,988,585,251,774,1131,1718,382,1822,1603,347,1089,144,217,1472,78,1629,1078,335,1580,1443,1803,365,717,1754,510,1104,1332,516,1404,949,488,1114,790,1394,719,238,1609,842,1533,1617,1260,391,987,1840,441,1660,1021,1653,1168,1338,598,1498,1427,161,232,1386,166,1515,938,1182,376,1115,1555,1370,619,770,1192,896,280,1242,948,1815,214,1180,459,677,1161,906,676,107,764,1591,1820,1019,180,1683,25,616,141,455,1302,1517,1437,688,782,1395,180,43,948,888,1570,776,824,374,29,1534,1654,1623,979,1472,809,135,451,420,1330,900,896,1731,1246,1538,565,796,619,443,382,97,1114,1303,1346,1361,1087,673,1831,1791,616,665,1565,191,647,713,606,1133,873,551,626,1528,1195,920,1095,162,1701,781,1279,1190,1231,692,1700,82,57,1600,1754,214,562,1314,734,1527,1706,548,1776,1081,1709,709,1358,379,1706,162,197,448,1057,1746,739,148,735,1784,875,1003,1676,1788,1239,1399,804,471,1304,298,580,1403,947,1561,1826,198,700,1447,806,966,162,926,1666,1028,1128,1643,1619,1563,413,704,1021,1569,1594,641,476,1456,28,1397,28,674,762,1244,1632,611,816,1351,1084,538,128,1705,145,78,529,1503,632,1462,263,1801,357,985,771,382,91,1300,1121,711,691,246,561,595,835,570,1305,1750,331,430,314,1655,1189,296,688,31,1811,1746,1577,1304,1781,1701,470,551,535,1612,313,164,888,1782,758,1545,1744,1697,1118,247,1191,883,947,255,568,1179,473,108,496,1351,1697,474,1683,1037,1211,422,1381,1175,1419,1383,1139,1802,888,1601,728,1806,129,1537,51,1528,160,582,1243,295,41,1509,693,694,503,1233,349,1216,1118,1724,99,1480,650,606,321,1191,1611,1689,1421,650,1760,1562,1010,525,289,705,248,849,1361,1089,294,830,1724,244,1419,1124,82,350,875,1230,1182,1590,222,1732,657,1308,1396,1817,323,1173,967,300,300,1354,1640,1009,413,509,921,750,1297,1462,1384,1290,215,664,1805,1022,1189,951,1704,721,599,334,39,901,621,956,1753,1472,110,446,242,1028,257,511,1234,148,1180,389,1001,362,758,1670,394,476,982,732,386,1643,1746,1782,361,1785,659,1329,945,732,1643,85,525,1002,498,413,1181,368,522,1760,796,1070,1245,1196,1392,165,722,1522,720,1240,351,1446,1817,1152,1809,651,920,1643,76,1595,1349,986,156,590,525,1043,516,745,1418,169,717,492,1344,1029,330,1291,674,254,1818,828,805,818,1782,234,637,558,678,842,52,672,1246,971,75,348,774,1118,1232,352,1120,150,1726,1313,822,457,770,1043,169,216,1667,813,1188,666,785,1298,455,1037,271,1610,1764,806,1503,1268,494,1048,1115,316,1637,418,22,1703,613,1118,1255,934,672,1251,612,1778,844,1499,1156,1082,868,1114,801,769,67,519,1610,1110,775,838,210,1337,755,1415,141,1778,321,625,1350,1739,1164,72,854,728,25,169,1685,654,767, ...

# %% [markdown]
# # **Pay-for-Performance**

# %%
import numpy as np

df_jittered = df_people.with_columns(
    (pl.col('performance_score') + (pl.lit(0.1) * (pl.lit(2) * pl.Series(np.random.rand(len(df_people))) - pl.lit(1))))
    .alias('performance_score_jittered')
)

display(df_jittered)
# Out:
# shape: (2_500, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ employee_ ┆ gender    ┆ departmen ┆ job_level ┆ … ┆ potential ┆ is_attrit ┆ tenure_in ┆ performa │
# │ id        ┆ ---       ┆ t         ┆ ---       ┆   ┆ _score    ┆ ed        ┆ _days     ┆ nce_scor │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ e_jitter │
# │ i64       ┆           ┆ str       ┆           ┆   ┆ i64       ┆ i64       ┆ i64       ┆ ed       │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8273      ┆ Male      ┆ Finance   ┆ T1        ┆ … ┆ 2         ┆ 0         ┆ 1703      ┆ 4.959056 │
# │ 8790      ┆ Non-Binar ┆ Sales     ┆ T1        ┆ … ┆ 3         ┆ 1         ┆ 8         ┆ 4.93299  │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 7634      ┆ Female    ┆ Data      ┆ T5        ┆ … ┆ 2         ┆ 1         ┆ 507       ┆ 1.9308   │
# │ 3829      ┆ Female    ┆ Product   ┆ T1        ┆ … ┆ 2         ┆ 1         ┆ 33        ┆ 1.062314 │
# │ 4618      ┆ Non-Binar ┆ Product   ┆ T2        ┆ … ┆ 5         ┆ 0         ┆ 462       ┆ 2.98577  │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 5970      ┆ Non-Binar ┆ Human     ┆ T2        ┆ … ┆ 4         ┆ 0         ┆ 1447      ┆ 2.942768 │
# │           ┆ y         ┆ Resources ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 3563      ┆ Non-Binar ┆ Human     ┆ T3        ┆ … ┆ 1         ┆ 0         ┆ 1812      ┆ 4.030684 │
# │           ┆ y         ┆ Resources ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2643      ┆ Male      ┆ Data      ┆ T3        ┆ … ┆ 3         ┆ 0         ┆ 943       ┆ 0.918945 │
# │ 8038      ┆ Male      ┆ Sales     ┆ T2        ┆ … ┆ 4         ┆ 0         ┆ 1347      ┆ 3.007449 │
# │ 5561      ┆ Male      ┆ Product   ┆ T4        ┆ … ┆ 5         ┆ 0         ┆ 1313      ┆ 4.04322  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
fig_scatter = px.scatter(
    df_jittered.to_pandas(),
    x='performance_score_jittered',
    y='base_salary',
    color='job_level',
    opacity=0.5, # Make points semi-transparent to see density
    title='Pay-for-Performance: Salary vs Performance Score',
    labels={'performance_score_jittered':'Performance Score','base_salary':'Base Salary (€)'},
    trendline='ols'
)

fig_scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4aff794e-ce9c-4d90-a753-0eedcaf6f99f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aff794e-ce9c-4d90-a753-0eedcaf6f99f")) {                    Plotly.newPlot(                        "4aff794e-ce9c-4d90-a753-0eedcaf6f99f",                        [{"hovertemplate":"job_level=T1\u003cbr\u003ePerformance Score=%{x}\u003cbr\u003eBase Salary (€)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T1","marker":{"color":"#636efa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"T1","showlegend":true,"x":[4.959056029668992,4.932989604243243,1.0623140931930113,1.090223218382996,4.973938167182467,5.097436673577302,2.9546892335490598,5.088203148400659,1.0202436950566538,2.068749936799753,4.914792029915739,5.050482751007566,4.026987949174471,2.949782493334241,2.9318400305409607,3.911969634906642,0.9598062089228959,1.9895228942255536,4.903035720444398,2.0466393093909083,5.008971476694228,2.0085249281380175,1.9759876785570039,4.031664479684843,3.956555789387691,2.0851953357787556,1.070309492710677,4.951164785729172,1.9673582594375363,4.938385536562042,0.9653900827012216,1.0442783714363655,3.047575289538408,3.0777897866753383,2.9350144181687057,2.0333121371289153,1.9898718676371214,2.001127396905327,0.9379785213363789,4.956802399267458,2.0801851663364976,0.9209985696217671,5.058201412486791,5.007561281845127,5.0849124089639375,0.9242553211109811,3.04674738608661,2.077625134043531,2.9658231652106273,1.902512383559938,2.036585104888876,4.985692509905206,3.9021025086695613,1.923906603655166,4.91393377474536,0.9029484387146881,1.9478526034776855,2.91866436886595,0.9151106533438895,2.9712232592644208,2.911829507666734,1.0374695144120407,4.925042052722395,4.074439636217263,2.9968902947455076,3.0298830089680413,1.0556229889602928,4.9388319515294175,3.9197430760175225,3.0510409920139856,4.0446232300421086,2.950103409988649,0.9389716785121229,4.923137571591897,4.999738514507968,2.982617757867874,4.945645202239214,3.01533616061925,0.9697956769795156,0.9276804459157318,2.037613849056013,0.9389049191531821,3.958624478781507,4.094117447196802,3.935859979997573,2.0138644202974367,1.0866624612757807,1.9540845320147842,5.028981267458042,2.0864132288481363,2.0268076917485924,4.075115169992019,2.072151873969367,1.9824797031645869,2.9794628382890727,1.9480052679402329,2.0346508551942266,4.060848047530192,5.0452287023325155,3.9829706383031627,1.941056979460113,1.07252948321536,5.042490175546857,1.0289136829565553,2.0476307992018823,3.0456673332073008,4.015317052087636,5.04966320058858,4.05322184291041,3.0412330811434427,4.061844487174311,5.0072896259702215,5.062731208439538,4.970468377172002,2.064452483892561,3.097579567356856,4.929187615821778,2.953565780340517,4.034787355904632,1.9172625794511466,1.0066654981404661,0.9893379386444231,5.050537724280409,1.9957440617263404,2.9977028978964997,3.984641747477355,2.094967071755797,0.9175555797154087,1.9888753258960157,4.0157428654588365,2.964035135451387,3.9432307108240012,0.9639476402491426,3.0239472160714276,1.9145029541516156,1.9842863752611724,5.0922648242869775,1.9266484196039868,3.054857898016706,1.9854398155745316,2.0471626042118762,2.023298629156617,3.944623748351558,4.0537306981693035,2.0619743495958813,5.031944572474204,4.957144216916329,4.909452134302068,2.081852229121411,2.0751486983145755,5.079275557195662,5.0688885949378015,5.027038175413887,4.943509421094316,4.079514284430641,3.998398019905563,3.9250926897368394,5.097007686454426,4.9060500540210965,2.0130184352262703,3.0101358753147287,3.0646426324541793,5.083886633350511,1.0195160016158953,2.9260416087266417,1.9252548712151063,0.9049119883184337,0.9016971764332586,1.0686153418927855,0.9466676475833697,5.039854783512767,2. ...

# %% [markdown]
# # **Company Composition**

# %%
sunburst_data = df_with_status.group_by(
    ['department','job_level','Attrition Status']
).agg(
    pl.len().alias('count')
)

display(sunburst_data)
# Out:
# shape: (60, 4)
# ┌─────────────────┬───────────┬──────────────────┬───────┐
# │ department      ┆ job_level ┆ Attrition Status ┆ count │
# │ ---             ┆ ---       ┆ ---              ┆ ---   │
# │ str             ┆ str       ┆ str              ┆ u32   │
# ╞═════════════════╪═══════════╪══════════════════╪═══════╡
# │ Data            ┆ T2        ┆ Stayed           ┆ 72    │
# │ Sales           ┆ T1        ┆ Stayed           ┆ 71    │
# │ Human Resources ┆ T1        ┆ Stayed           ┆ 61    │
# │ Sales           ┆ T4        ┆ Left             ┆ 7     │
# │ Engineering     ┆ T3        ┆ Stayed           ┆ 61    │
# │ …               ┆ …         ┆ …                ┆ …     │
# │ Engineering     ┆ T3        ┆ Left             ┆ 16    │
# │ Sales           ┆ T3        ┆ Stayed           ┆ 72    │
# │ Finance         ┆ T5        ┆ Left             ┆ 17    │
# │ Human Resources ┆ T5        ┆ Stayed           ┆ 72    │
# │ Sales           ┆ T1        ┆ Left             ┆ 19    │
# └─────────────────┴───────────┴──────────────────┴───────┘

# %%
fig_sunburst = px.sunburst(
    sunburst_data.to_pandas(),
    path=['department','job_level','Attrition Status'],
    values='count',
    title='Company Composition by Department, Job Level and Attrition'
)

fig_sunburst.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2225e41-b0b4-4add-b07c-bf663f338ec6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2225e41-b0b4-4add-b07c-bf663f338ec6")) {                    Plotly.newPlot(                        "c2225e41-b0b4-4add-b07c-bf663f338ec6",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Data\u002fT1\u002fLeft","Engineering\u002fT1\u002fLeft","Finance\u002fT1\u002fLeft","Human Resources\u002fT1\u002fLeft","Product\u002fT1\u002fLeft","Sales\u002fT1\u002fLeft","Data\u002fT2\u002fLeft","Engineering\u002fT2\u002fLeft","Finance\u002fT2\u002fLeft","Human Resources\u002fT2\u002fLeft","Product\u002fT2\u002fLeft","Sales\u002fT2\u002fLeft","Data\u002fT3\u002fLeft","Engineering\u002fT3\u002fLeft","Finance\u002fT3\u002fLeft","Human Resources\u002fT3\u002fLeft","Product\u002fT3\u002fLeft","Sales\u002fT3\u002fLeft","Data\u002fT4\u002fLeft","Engineering\u002fT4\u002fLeft","Finance\u002fT4\u002fLeft","Human Resources\u002fT4\u002fLeft","Product\u002fT4\u002fLeft","Sales\u002fT4\u002fLeft","Data\u002fT5\u002fLeft","Engineering\u002fT5\u002fLeft","Finance\u002fT5\u002fLeft","Human Resources\u002fT5\u002fLeft","Product\u002fT5\u002fLeft","Sales\u002fT5\u002fLeft","Data\u002fT1\u002fStayed","Engineering\u002fT1\u002fStayed","Finance\u002fT1\u002fStayed","Human Resources\u002fT1\u002fStayed","Product\u002fT1\u002fStayed","Sales\u002fT1\u002fStayed","Data\u002fT2\u002fStayed","Engineering\u002fT2\u002fStayed","Finance\u002fT2\u002fStayed","Human Resources\u002fT2\u002fStayed","Product\u002fT2\u002fStayed","Sales\u002fT2\u002fStayed","Data\u002fT3\u002fStayed","Engineering\u002fT3\u002fStayed","Finance\u002fT3\u002fStayed","Human Resources\u002fT3\u002fStayed","Product\u002fT3\u002fStayed","Sales\u002fT3\u002fStayed","Data\u002fT4\u002fStayed","Engineering\u002fT4\u002fStayed","Finance\u002fT4\u002fStayed","Human Resources\u002fT4\u002fStayed","Product\u002fT4\u002fStayed","Sales\u002fT4\u002fStayed","Data\u002fT5\u002fStayed","Engineering\u002fT5\u002fStayed","Finance\u002fT5\u002fStayed","Human Resources\u002fT5\u002fStayed","Product\u002fT5\u002fStayed","Sales\u002fT5\u002fStayed","Data\u002fT1","Engineering\u002fT1","Finance\u002fT1","Human Resources\u002fT1","Product\u002fT1","Sales\u002fT1","Data\u002fT2","Engineering\u002fT2","Finance\u002fT2","Human Resources\u002fT2","Product\u002fT2","Sales\u002fT2","Data\u002fT3","Engineering\u002fT3","Finance\u002fT3","Human Resources\u002fT3","Product\u002fT3","Sales\u002fT3","Data\u002fT4","Engineering\u002fT4","Finance\u002fT4","Human Resources\u002fT4","Product\u002fT4","Sales\u002fT4","Data\u002fT5","Engineering\u002fT5","Finance\u002fT5","Human Resources\u002fT5","Product\u002fT5","Sales\u002fT5","Data","Engineering","Finance","Human Resources","Product","Sales"],"labels":["Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","Stayed","T1","T1","T1","T1","T1","T1","T2","T2","T2","T2","T2","T2","T3","T3","T3","T3","T3","T3","T4","T4","T4","T4","T4","T4","T5","T5","T5","T5","T5","T5","Data","Engineering","Finance","Human Resources","Product","Sales"],"name":"","parents":["Data\u002fT1","Engineering\u0 ...
