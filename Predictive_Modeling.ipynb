# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/Equilibrium/blob/main/Predictive_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
from google.cloud import bigquery
from google.colab import auth
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import joblib
import plotly.express as px
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# %% [markdown]
# # **Data Extraction from BigQuery**

# %%
auth.authenticate_user()
project_id = 'project-equilibrium-474307'
client = bigquery.Client(project_id)
print('Authentication Successfull')
# Out:
# Authentication Successfull

# %%
master_query = f"""
WITH LatestPerformance AS (
  SELECT
    employee_id,
    performance_score,
    potential_score,
    ROW_NUMBER() OVER(PARTITION BY employee_id ORDER BY review_date DESC) AS rn
  FROM
    `project-equilibrium-474307.hr_analytics.performance`
),
LatestCompensation AS (
  SELECT
    employee_id,
    base_salary,
    bonus,
    stock_options,
    ROW_NUMBER() OVER(PARTITION BY employee_id ORDER BY effective_date DESC) AS rn
  FROM
    `project-equilibrium-474307.hr_analytics.compensation`
)
SELECT
  e.employee_id,
  e.gender,
  e.department,
  e.job_level,
  e.hire_date,
  e.termination_date,
  lc.base_salary,
  lc.bonus,
  lc.stock_options,
  lp.performance_score,
  lp.potential_score,
  CASE WHEN e.termination_date IS NOT NULL THEN 1 ELSE 0 END AS is_attrited,
  DATE_DIFF(COALESCE(e.termination_date, '2025-10-16'), e.hire_date, DAY) AS tenure_in_days
FROM
  `project-equilibrium-474307.hr_analytics.employees` AS e
LEFT JOIN LatestCompensation AS lc
  ON e.employee_id = lc.employee_id AND lc.rn = 1
LEFT JOIN LatestPerformance AS lp
  ON e.employee_id = lp.employee_id AND lp.rn = 1
WHERE
  lc.base_salary IS NOT NULL AND lp.performance_score IS NOT NULL;
"""

# %%
pandas_df = client.query(master_query).to_dataframe()
df_people = pl.from_pandas(pandas_df)

# %%
print(f'Data Successfully Extracted. Shape:{df_people.shape}')
# Out:
# Data Successfully Extracted. Shape:(2500, 13)

# %%
df_people.head()
# Out:
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ employee_ ┆ gender    ┆ departmen ┆ job_level ┆ … ┆ performan ┆ potential ┆ is_attrit ┆ tenure_i │
# │ id        ┆ ---       ┆ t         ┆ ---       ┆   ┆ ce_score  ┆ _score    ┆ ed        ┆ n_days   │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆           ┆ str       ┆           ┆   ┆ i64       ┆ i64       ┆ i64       ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8273      ┆ Male      ┆ Finance   ┆ T1        ┆ … ┆ 5         ┆ 2         ┆ 0         ┆ 1703     │
# │ 8790      ┆ Non-Binar ┆ Sales     ┆ T1        ┆ … ┆ 5         ┆ 3         ┆ 1         ┆ 8        │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 7634      ┆ Female    ┆ Data      ┆ T5        ┆ … ┆ 2         ┆ 2         ┆ 1         ┆ 507      │
# │ 3829      ┆ Female    ┆ Product   ┆ T1        ┆ … ┆ 1         ┆ 2         ┆ 1         ┆ 33       │
# │ 4618      ┆ Non-Binar ┆ Product   ┆ T2        ┆ … ┆ 3         ┆ 5         ┆ 0         ┆ 462      │
# │           ┆ y         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# # **Feature Engineering & Preprocessing**

# %%
# Convert date columns to numerical features
df_hr = df_people.with_columns(
    pl.col('hire_date').dt.ordinal_day().alias('hire_date_ordinal'),
)

# %%
# One-Hot Encode Categorical Variables
df_hr = df_people.to_dummies(columns=['gender','ethnicity','department','job_level'])

# %%
# Handling any potential missing values
df_hr = df_people.fill_null(strategy='mean')

# %%
print('Feature engineering complete. New shape:',df_hr.shape)
# Out:
# Feature engineering complete. New shape: (2500, 13)

# %% [markdown]
# # **Model 1 - Attrition Prediction (Classification)**

# %%
# Defining features X and target y
# Dropping non-predictive columns and the target itself

features_attrition = df_hr.drop(['employee_id','hire_date','termination_date','is_attrited','base_salary'])
target_attrition = df_hr['is_attrited']

# One-Hot Encode Categorical Variables before splitting
features_attrition = features_attrition.to_dummies(columns=['gender','department','job_level'])

# %%
# Splitting the data into training and testing sets
X_train,X_test,y_train,y_test = train_test_split(
    features_attrition,target_attrition,test_size=0.25,random_state=42,stratify=target_attrition
)

# One-Hot Encode Categorical Variables after splitting
X_train = X_train.to_dummies(columns=['gender','department','job_level'])
X_test = X_test.to_dummies(columns=['gender','department','job_level'])

# %%
# Initializing and train the random Forest Classifier
attrition_model = RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')
attrition_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
# Making Predictions on the test set
y_pred = attrition_model.predict(X_test)

# %%
# Evaluating my model
print('\nClassification Report:')
print(classification_report(y_test,y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89       515
#            1       0.25      0.05      0.09       110
#
#     accuracy                           0.80       625
#    macro avg       0.54      0.51      0.49       625
# weighted avg       0.73      0.80      0.75       625

# %%
print('Confusion Matrix')
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# Confusion Matrix
# [[497  18]
#  [104   6]]

# %%
fig = px.imshow(
    cm,
    labels=dict(x='Predicted Label',y='True Label'),
    x=['Predicted Stay (0)','Predicted Leave (1)'],
    y=['True Stay (0)','True Leave (1)'],
    text_auto=True,
    title='Attrition Model Confusion Matrix',
    color_continuous_scale=px.colors.sequential.Viridis_r
)

fig.update_layout(
    xaxis=dict(side='top'),
    title_x=0.5
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f6b6ecc5-aa45-40bc-9742-f8aa91701256" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6b6ecc5-aa45-40bc-9742-f8aa91701256")) {                    Plotly.newPlot(                        "f6b6ecc5-aa45-40bc-9742-f8aa91701256",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Predicted Stay (0)","Predicted Leave (1)"],"y":["True Stay (0)","True Leave (1)"],"z":[[497,18],[104,6]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Predicted Label: %{x}\u003cbr\u003eTrue Label: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"typ ...

# %%
# Displaying Feature Importances
print('\nTop Five Drivers of Attrition (as %):')
feature_importances = pd.Series(attrition_model.feature_importances_,index=features_attrition.columns).sort_values(ascending=False)

# Converting to percentage, sort and format
feature_importances_percent = (feature_importances * 100).sort_values(ascending=False)
formatted_importances = feature_importances_percent.head(5).map('{:.0f}%'.format)

display(formatted_importances)
# Out:
# Top Five Drivers of Attrition (as %):
# tenure_in_days       33%
# bonus                17%
# performance_score    11%
# stock_options         8%
# potential_score       7%
# dtype: object

# %%
feature_importances = pd.Series(attrition_model.feature_importances_, index=features_attrition.columns)
feature_importances_percent = (feature_importances * 100).sort_values(ascending=False)

# %%
# Creating a DataFrame for Plotly
importance_df = pl.DataFrame({
    'feature': feature_importances_percent.index,
    'importance_pct':feature_importances_percent.values
})

# %%
# Getting the top 15 features for the plot
top_15_features = importance_df.head(15)
display(top_15_features)
# Out:
# shape: (15, 2)
# ┌────────────────────────────┬────────────────┐
# │ feature                    ┆ importance_pct │
# │ ---                        ┆ ---            │
# │ str                        ┆ f64            │
# ╞════════════════════════════╪════════════════╡
# │ tenure_in_days             ┆ 32.913425      │
# │ bonus                      ┆ 16.932375      │
# │ performance_score          ┆ 10.5957        │
# │ stock_options              ┆ 7.504283       │
# │ potential_score            ┆ 7.149789       │
# │ …                          ┆ …              │
# │ job_level_T2               ┆ 1.831459       │
# │ department_Human Resources ┆ 1.813532       │
# │ gender_Female              ┆ 1.796428       │
# │ department_Data            ┆ 1.783673       │
# │ department_Product         ┆ 1.755895       │
# └────────────────────────────┴────────────────┘

# %%
fig_imp = px.bar(
    top_15_features,
    x='importance_pct',
    y='feature',
    orientation='h',
    title='Top 15 Feature Importances for Attrition Prediction',
    labels={'importance_pct':'Importance (%)','feature':'Feature'},
    text='importance_pct',
    color='feature',
    color_discrete_sequence=px.colors.qualitative.Pastel
)

fig_imp.update_layout(
    yaxis=dict(autorange='reversed'),
    title_x=0.5,
    showlegend=False
)
fig_imp.update_traces(texttemplate='%{text:.0f}%',textposition='outside')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f9cf2889-c823-40de-be6a-e44868957fbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9cf2889-c823-40de-be6a-e44868957fbd")) {                    Plotly.newPlot(                        "f9cf2889-c823-40de-be6a-e44868957fbd",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"tenure_in_days","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"tenure_in_days","offsetgroup":"tenure_in_days","orientation":"h","showlegend":true,"text":[32.913425104052926],"textposition":"outside","x":[32.913425104052926],"xaxis":"x","y":["tenure_in_days"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bonus","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"bonus","offsetgroup":"bonus","orientation":"h","showlegend":true,"text":[16.93237540449839],"textposition":"outside","x":[16.93237540449839],"xaxis":"x","y":["bonus"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"performance_score","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"performance_score","offsetgroup":"performance_score","orientation":"h","showlegend":true,"text":[10.595699698731153],"textposition":"outside","x":[10.595699698731153],"xaxis":"x","y":["performance_score"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"stock_options","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"stock_options","offsetgroup":"stock_options","orientation":"h","showlegend":true,"text":[7.504283233159112],"textposition":"outside","x":[7.504283233159112],"xaxis":"x","y":["stock_options"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"potential_score","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"potential_score","offsetgroup":"potential_score","orientation":"h","showlegend":true,"text":[7.149789007177033],"textposition":"outside","x":[7.149789007177033],"xaxis":"x","y":["potential_score"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"job_level_T4","marker":{"color":"rgb(158, 185, 243)","pattern":{"shape":""}},"name":"job_level_T4","offsetgroup":"job_level_T4","orientation":"h","showlegend":true,"text":[2.0612905871401956],"textposition":"outside","x":[2.0612905871401956],"xaxis":"x","y":["job_level_T4"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"job_level_T5","marker":{"color":"rgb(254, 136, 177)","pattern":{"shape":""}},"name":"job_level_T5","offsetgroup":"job_level_T5","orientation":"h","showlegend":true,"text":[1.910521210100867],"textposition":"outside","x":[1.910521210100867],"xaxis":"x","y":["job_level_T5"],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}%"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eImportance (%)= ...

# %% [markdown]
# # **Model 2 - Salary Prediction (Regression)**
#
# ---

# %%
# Defining features (X) and target (y)
features_salary = df_people.drop(['employee_id','hire_date','termination_date','is_attrited','base_salary'])
target_salary = df_people['base_salary']

# %%
# Splitting the Data
X_train_sal,X_test_sal,y_train_sal,y_test_sal = train_test_split(
    features_salary,target_salary,test_size=0.25,random_state=42
)

# One-Hot Encode Categorical Variables after splitting
X_train_sal = X_train_sal.to_dummies(columns=['gender','department','job_level'])
X_test_sal = X_test_sal.to_dummies(columns=['gender','department','job_level'])

# %%
# Initialize and train the Random Forest Regressor
salary_model = RandomForestRegressor(n_estimators=100,random_state=42)
salary_model.fit(X_train_sal,y_train_sal)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Making predictions
y_pred_sal = salary_model.predict(X_test_sal)

# %%
# Evaluate the model
r2 = r2_score(y_test_sal, y_pred_sal)
mae = mean_absolute_error(y_test_sal,y_pred_sal)

# %%
print(f'\nR-squared: {r2:.2f}')
print(f'Mean Absolute Error (MAE): €{mae:,.2f}')
# Out:
# R-squared: 0.81
# Mean Absolute Error (MAE): €7,957.63
